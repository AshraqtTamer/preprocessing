# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import scipy.stats as st
warnings.filterwarnings('ignore')

# %%
sns.set_style("whitegrid")
# style graph in seaborn

# %%
df=pd.read_csv('/content/Absenteeism_at_work.csv',sep=';')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# 5     3                  23                 7                6        1
# 6    10                  22                 7                6        1
# 7    20                  23                 7                6        1
# 8    14                  19                 7                2        1
# 9     1                  22                 7                2        1
# 10   20                   1                 7                2        1
# 11   20                   1                 7                3        1
# ...

# %%
pd.set_option('display.max.columns',21)
pd.set_option('display.max.rows',740)
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# 5     3                  23                 7                6        1
# 6    10                  22                 7                6        1
# 7    20                  23                 7                6        1
# 8    14                  19                 7                2        1
# 9     1                  22                 7                2        1
# 10   20                   1                 7                2        1
# 11   20                   1                 7                3        1
# ...

# %%
print(df.shape)
# Out:
# (740, 21)

# %%
print(df.columns)
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
df.tail()
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 735                     289                               36            13
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
df[["Month of absence","Transportation expense","Distance from Residence to Work", "Hit target","Education","Weight","Height",
"Body mass index","Absenteeism time in hours"]]=df[["Month of absence","Transportation expense","Distance from Residence to Work", "Hit target","Education","Weight","Height",
"Body mass index","Absenteeism time in hours"]].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    float64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    float64
#  6   Distance from Residence to Work  740 non-null    float64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    float64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
df.drop(['ID','Pet'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.324324         3.914865    2.544595
# std              8.433406          3.436287         1.421675    1.111831
# min              0.000000          0.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
df['Month of absence'].replace(0,1,inplace=True)

# %%
print(df.describe())
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.328378         3.914865    2.544595
# std              8.433406          3.429397         1.421675    1.111831
# min              0.000000          1.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
df.isnull().sum()
# Out:
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
assert pd.notnull(df).all().all()

# %%
assert (df>=0).all().all()

# %%
print(df['Absenteeism time in hours'].describe())
# Out:
# count    740.000000
# mean       6.924324
# std       13.330998
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        8.000000
# max      120.000000
# Name: Absenteeism time in hours, dtype: float64

# %%
df['Absenteeism time in hours'].skew()
# Out:
# 5.720727863123873

# %%
plt.figure(figsize= (10,8))
sns.distplot(df["Absenteeism time in hours"])
plt.title("Distribution of Absenteeism time in hours")
plt.show()

# %%
df['Absenteeism time in hours'].kurt()
# Out:
# 38.77730707753998

# %%
y=df['Absenteeism time in hours']

# %%
plt.figure(figsize=(10,5))
sns.distplot(y,kde=False,fit=st.norm)
plt.title('Distribution of Absenteeism time in hours')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.distplot(y, kde=False, fit=st.lognorm)
plt.title('Log Normal fit')
plt.show()

# %%
counts=df['Seasons'].value_counts()

# %%
df['Seasons'].value_counts().plot(kind='bar')
plt.title('Seasons vs Absenteeism time in hours')
plt.xlabel('Seasons')
plt.ylabel('Absenteeism time in hours')
plt.legend()
plt.show()

# %%
df['Education'].value_counts()
# Out:
# Education
# 1.0    611
# 3.0     79
# 2.0     46
# 4.0      4
# Name: count, dtype: int64

# %%
df['Education'].value_counts().plot(kind='bar')
plt.title('Education vs Absenteeism time in hours')
plt.xlabel('Education')
plt.ylabel('Absenteeism time in hours')
plt.legend()
plt.show()

# %%
socialdrinkers=df['Social drinker'].value_counts()

# %%
socialdrinkers.plot(kind='bar')
plt.title('Social drinker vs Absenteeism time in hours')
plt.xlabel('Social drinker')
plt.ylabel('Absenteeism time in hours')
plt.legend()
plt.show()

# %%
smoker=df['Social smoker'].value_counts()

# %%
smoker.plot(kind='bar')
plt.title('Social smoker vs Absenteeism time in hours')
plt.xlabel('Social smoker')
plt.ylabel('Absenteeism time in hours')
plt.legend()
plt.show()

# %%
correlations=df.corr()

# %%
correlations['Absenteeism time in hours'].sort_values(ascending=False)
# Out:
# Absenteeism time in hours          1.000000
# Height                             0.144420
# Son                                0.113756
# Age                                0.065760
# Social drinker                     0.065067
# Transportation expense             0.027585
# Hit target                         0.026695
# Work load Average/day              0.024749
# Month of absence                   0.023779
# Service time                       0.019029
# Weight                             0.015789
# Seasons                           -0.005615
# Social smoker                     -0.008936
# Education                         -0.046235
# Body mass index                   -0.049719
# Distance from Residence to Work   -0.088363
# Disciplinary failure              -0.124248
# Day of the week                   -0.124361
# Reason for absence                -0.173116
# Name: Absenteeism time in hours, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlations,annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
num_var = ['Transportation expense', 'Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ',
           'Absenteeism time in hours']
sns.pairplot(df[num_var], kind='scatter', diag_kind='scatter')
plt.show()

# %%
sns.lmplot(x='Absenteeism time in hours', y='Height', data=df)
plt.show()
#

# %%
ax=sns.boxplot(x='Age',y='Absenteeism time in hours',data=df)
ax
# Out:
# <Axes: xlabel='Age', ylabel='Absenteeism time in hours'>
